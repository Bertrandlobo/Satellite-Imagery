# %%
# !pip install earthpy gdal

# %%
from glob import glob

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

# %%
import rasterio as rio
from rasterio.plot import plotting_extent
from rasterio.plot import show
from rasterio.plot import reshape_as_raster, reshape_as_image

import os

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

import plotly.graph_objects as go

np.seterr(divide = 'ignore', invalid = 'ignore')
# Out:
# {'divide': 'ignore', 'over': 'warn', 'under': 'ignore', 'invalid': 'ignore'}

# %%
os.chdir("/Users/bertrandlobo/Downloads/Amazon_Rawdata/")

# %%
bands = glob("*B*.tiff")

# %%
bands.sort()
bands
# Out:
# ['2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B01_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B02_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B03_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B04_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B05_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B06_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B07_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B08_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B09_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B10_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B11_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B12_(Raw).tiff',
#  '2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B8A_(Raw).tiff']

# %%
src = rio.open("2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B01_(Raw).tiff")

# %%
type(src)
# Out:
# rasterio.io.DatasetReader

# %%
from rasterio.plot import show

# %%
show(src)
# Out:
# <AxesSubplot:>

# %%
src = rio.open("2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B02_(Raw).tiff")
type(src)
from rasterio.plot import show
show(src)
# Out:
# <AxesSubplot:>

# %%
src = rio.open("2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B03_(Raw).tiff")
type(src)
from rasterio.plot import show
show(src)
# Out:
# <AxesSubplot:>

# %%
src = rio.open("2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B04_(Raw).tiff")
type(src)
from rasterio.plot import show
show(src)
# Out:
# <AxesSubplot:>

# %%
src = rio.open("2022-04-28-00:00_2022-04-28-23:59_Sentinel-2_L1C_B05_(Raw).tiff")
type(src)
from rasterio.plot import show
show(src)
# Out:
# <AxesSubplot:>

# %%
# !pip install nbconvert

# %%
# !pip install pandoc

# %%
jupyter nbconvert --to pdf Plotting_The Amazon.ipynb
# Out:
#   File "/var/folders/3g/_gp52rk94rb9kttsv_01095c0000gn/T/ipykernel_9817/944880444.py", line 1
#     jupyter nbconvert --to pdf Plotting_The Amazon.ipynb
#             ^
# SyntaxError: invalid syntax
